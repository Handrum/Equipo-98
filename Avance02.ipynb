# %% [markdown]
# <a href="https://colab.research.google.com/github/Handrum/Equipo-98/blob/main/Avance02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Día 17 de Septiembre, el servidor presentó caída en la red.")
# Out:
# Día 17 de Septiembre, el servidor presentó caída en la red.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
